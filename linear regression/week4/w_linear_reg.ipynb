# %% [markdown]
# ## Lab Session 5
# ### Lab Outcomes
# In this lab session you will learn how to:
# * Implement linear regression with w as variable
# * Real world based prediction and enhancement in linear regression
# * Difference between old and new linear regression model
# * Visual Difference between Good, Better and Best Fitting model

# %% [markdown]
# Use the `Housing.csv` file as dataset and import it with `pandas` and plotting through `matplotlib`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('w_hpp.csv')

# %% [markdown]
# ### Note:
# If there is main road infront of house then value will be `2` otherwise it will near main road then value will be `1`

# %%
df.head()
# Out:
#       price  area  mainroad  bias
# 0  13300000  7420       1.9   700
# 1  12250000  8960       1.5   800
# 2  12250000  9960       1.3   900
# 3  12215000  7500       1.9   700
# 4  11410000  7420       1.5   700

# %% [markdown]
# We need first two columns like `price`, `area` and `mainroad` . So, let first make three variables.

# %%
x_train = df.iloc[:, 1]
y_train = df.iloc[:, 0]
w_train = df.iloc[:, 2]

# %%
b = 100

# %% [markdown]
# we are going to compute  `compute_model_w` function

# %%
def compute_model_W(x, w, b):
    m = np.shape(x)[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w[i]*x[i] + b
    return f_wb

# %% [markdown]
# Now its time to plot the Linear Regression `Model` function with `w` as variable to check the output on real world based scanerio

# %%
output = compute_model_W(x_train, w_train, b)
plt.plot(x_train, output, c= 'b', label = 'Prediction')
plt.scatter(x_train, y_train, c= 'r',marker='x', label='Data')
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
output = compute_model_W(x_train, w_train, b)
plt.plot(x_train, output, c= 'b', label = 'Prediction')
plt.title("Housing Prices with main road")
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
plt.scatter(x_train, y_train, c= 'r',marker='x', label='Data')
plt.title("Housing Prices with main road")
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# ### Difference in prediction between two models

# %%
wf = 100

# %%
def compute_model_func(x, w, b):
    # number of training examples
    m = np.shape(x)[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
    return f_wb

# %%
def compute_model_W(x, w, b):
    m = np.shape(x)[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w[i]*x[i] + b
    return f_wb

# %%
output = compute_model_W(x_train, w_train, b)
output1 = compute_model_func(x_train, wf, b)
plt.plot(x_train, output, c= 'b', label = 'New')
plt.plot(x_train, output1, c= 'r', label = 'Old')
plt.title("Model Accurary")
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# ### B as variable

# %%
b_train = df.iloc[:, 3]

# %%
def compute_model_wb(x,w,b):
    m = np.shape(x)[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w[i]*x[i] + b[i]
    return f_wb

# %%
output_last = compute_model_wb(x_train, w_train, b_train)
plt.plot(x_train, output_last, c= 'g', label = 'Prediction')
plt.scatter(x_train, y_train, c= 'r',marker='x', label='Data')
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
output = compute_model_W(x_train, w_train, b)
output1 = compute_model_func(x_train, wf, b)
output_last = compute_model_wb(x_train, w_train, b_train)
plt.plot(x_train, output1, c= 'r', label = 'Good')
plt.plot(x_train, output, c= 'b', label = 'better')
plt.plot(x_train, output_last, c= 'g', label = 'Best')
plt.title("Model Accurary")
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# ### Model 1
#  We use `Sizes` and predict `Prices`
# ### Model 2
#  We use `Sizes` with feature `Mainroad` predict `Prices`
# ### Model 3
#  We use `Sizes` with additional features like `Main Road`, `Enterence Areas` to predict `Prices`

# %%
output = compute_model_W(x_train, w_train, b)
output1 = compute_model_func(x_train, wf, b)
output_last = compute_model_wb(x_train, w_train, b_train)
plt.scatter(x_train, output1, c= 'r', label = 'Good')
plt.scatter(x_train, output, c= 'b', label = 'better')
plt.scatter(x_train, output_last, c= 'g',marker='x', label = 'Best')
plt.title("Model Accurary")
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()
