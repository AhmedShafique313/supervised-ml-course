# %% [markdown]
# ## Model Function
#  As described in lecture, the model function for linear regression (which is a function that maps from `x` to `y`) is represented as
#
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
#
# The formula above is how you can represent straight lines - different values of $w$ and $b$ give you different straight lines on the plot. <br/> <br/> <br/> <br/> <br/>
#
# Let's try to get a better intuition for this through the code blocks below. Let's start with $w = 100$ and $b = 100$.
#
# **Note: You can come back to this cell to adjust the model's w and b parameters**

# %%
w = 100
b = 100

# for user easiness 
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %% [markdown]
# Now, let's compute the value of $f_{w,b}(x^{(i)})$ for your two data points. You can explicitly write this out for each data point as -
#
# for $x^{(0)}$, `f_wb = w * x[0] + b`
#
# for $x^{(1)}$, `f_wb = w * x[1] + b`
#
# For a large number of data points, this can get unwieldy and repetitive. So instead, you can calculate the function output in a `for` loop as shown in the `compute_model` function below.
# > **Note**: The argument description `(ndarray (m,))` describes a Numpy n-dimensional array of shape (m,). `(scalar)` describes an argument without dimensions, just a magnitude.
# > **Note**: `np.zero(n)` will return a one-dimensional numpy array with $n$ entries

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
x_train = np.array([2.0, 5.0, 8.0])
y_train = np.array([300, 500, 1000])

# %%
def compute_model(x, w, b):
    #correct moethod
    m = np.shape(x)[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
    return f_wb

# %% [markdown]
# Let first plot the output of `compute_model` function

# %%
plot_output = compute_model(x_train, w, b)
# ploting prediction line
plt.plot(x_train, plot_output, c='b', label= 'Predcition')
# data points
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual data')
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# ### Extend data
# But if we extend the data to values to `7` entries then?

# %%
x_train = np.array([2.0, 5.0, 8.0, 13.0, 15.0, 16.0, 18.0])
y_train = np.array([300, 500, 1000, 1500, 2200, 2600, 3100])

# %%
plot_output = compute_model(x_train, w, b)
# ploting prediction line
plt.plot(x_train, plot_output, c='b', label= 'Predcition')
# data points
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual data')
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()
